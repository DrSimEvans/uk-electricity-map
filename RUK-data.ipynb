# %% [markdown]
# # RenewableUK battery storage site data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyproj
import re
import os
os.chdir('/Users/simon/Desktop/uk-map/')
# %matplotlib inline

# %%
wind = pd.read_csv('RenewableUK PI Onshore Wind Projects Operational 2019-04-08.csv')
storage = pd.read_csv('RenewableUK PI Storage Projects Operational 2019-04-08.csv')
store2 = pd.read_csv('RenewableUK PI Projects Under Construction 2019-04-11.csv')


# only contains three projects
# retired_battery = pd.read_csv('RenewableUK PI Storage Projects Ceased Operating 2019-04-08.csv')

# %%
# merge in the short list of under construction storage sites

storage = storage.append(store2, ignore_index=True)

# drop rows without data
storage.dropna(subset=['Project_Capacity_MW'], inplace=True)

#storage = storage.reindex()

# %%
# add missing storage capacity estimates

# Foyers figure from here:
# https://www.webarchive.org.uk/wayback/archive/20170113164926/http://www.gov.scot/Publications/2010/10/28091356/4

storage.Storage_Capacity_MWh[storage.Project == 'Foyers Pumped Storage'] = 6300

# calculate discharge time for lithium ion batteries

storage['Time'] = storage['Storage_Capacity_MWh'][
    storage.Generator_Type == 'Battery: Lithium-ion'] / storage[
        'Project_Capacity_MW'][storage.Generator_Type ==
                               'Battery: Lithium-ion']

# stratify battery sizes

storage['size'] = np.where(storage.Project_Capacity_MW <1,'tiny',np.nan)
storage['size'] = np.where(((storage.Project_Capacity_MW >=1)),'medium',storage['size'])
storage['size'] = np.where(((storage.Project_Capacity_MW >=10)),'large',storage['size'])

# find average time by size

discharge = storage[['Time','size']].groupby('size').mean().reset_index()
discharge.columns = ['size','avg']

# merge in the average per size bucket

storage = pd.merge(storage,discharge,left_on=['size'],right_on=['size'],how='left')
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# use the average discharge time if there is no figure

storage['Time'] = np.where(storage['Storage_Capacity_MWh'].isnull(),
                           storage['avg'], storage['Time'])

# use this estimated discharge time to calculate MWh

storage['Storage_Capacity_MWh'] = np.where(
    storage['Storage_Capacity_MWh'].isnull(),
    storage['Time'] * storage['Project_Capacity_MW'],
    storage['Storage_Capacity_MWh'])

# %%
# convert dates to date format

storage['Commissioned_Date'] = pd.to_datetime(storage['Commissioned_Date'], dayfirst=True)
storage['Construction_Date'] = pd.to_datetime(storage['Construction_Date'], dayfirst=True)

# %%
storage['Year Open'] = storage.Commissioned_Date.dt.year
storage['Year Started'] = storage.Construction_Date.dt.year

# use 2019 opening for projects under construction

storage['Year Open'][storage['Year Open'].isnull()] = 2019
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#storage[storage.Commissioned_Date.isnull()]

# %%
# select columns we want

storage = storage[[
    'Project', 'Project_Capacity_MW', 'Storage_Capacity_MWh', 'Time',
    'Generator_Type', 'UK_Region', 'Latitude_Decimal',
    'Longitude_Decimal', 'Year Open', 'Year Started','Owner'
]]

# rename the columns to match other datasets

storage.columns = [
    'Site', 'Capacity (MW)', 'Capacity (MWh)', 'Time', 'Type', 'Region',
    'Latitude', 'Longitude', 'Year Open', 'Year Started','Company'
]

# %%
# simplify types

storage['Type'][(storage.Site.str.contains('Battery')&(storage.Type.isnull()))] = 'Battery'
storage['Type'][(storage.Type.str.contains('Battery'))] = 'Battery'
storage['Type'][(storage.Type.str.contains('Pumped'))] = 'Pumped Hydro'

storage['Fuel'] = 'Storage'

storage['yearStart'] = storage['Year Open']

# assume batteries remain open in 2030
# may not be accurate
# this paper suggests perhaps 10 year lifetime
# https://www.nrel.gov/docs/fy17osti/67102.pdf

storage['yearEnd'] = 2019

# categorise as low carbon and renewable
# not accurate but best for viewing on the map

storage['Low-Carbon'] = 'Yes'
storage['Renewable'] = 'Yes'
storage['CHP'] = 'No'

# exclude the v small amount of capacity <1MW

storage = storage[storage['Capacity (MW)']>=1]
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
# save the file

storage.to_csv('storage.csv',index=False,encoding='utf-8')

# %% [markdown]
# # analysis and checks

# %%
storage.columns
# Out:
# Index([u'Project', u'Project_Capacity_MW', u'Type', u'Storage_Capacity_MWh',
#        u'Developer', u'Owner', u'Generator_Make', u'Generator_Model',
#        u'Number_of_Generators', u'Generator_Capacity', u'Generator_Type',
#        u'Country', u'County', u'UK_Region', u'Location', u'Sea_area', u'Lpa',
#        u'Latitude_Decimal', u'Longitude_Decimal', u'UKNatGridRef',
#        u'Hub_Height', u'Tip_Height', u'Rotor_Diameter', u'Summary_Status',
#        u'Status', u'Status_Date', u'SupersedeMethod', u'SupersedeByProject',
#        u'SupersededMethod', u'SupersededProject', u'Colocated_Grid',
#        u'Colocated_Grid_Detail', u'History', u'Submitted_Date',
#        u'Submitted_Note', u'Decision_Date', u'Decision_Note',
#        u'Appeal_Decision_Date', u'Appeal_Decision_Note', u'Construction_Date',
#        u'Construction_Note', u'Commissioned_Date', u'Commissioned_Note',
#        u'ResubmittedByProject', u'ResubmissionOfProject', u'Time', u'size',
#        u'avg'],
#       dtype='object')

# %%
storage['Project_Capacity_MW'][storage['Project_Capacity_MW']<1].sum()
# Out:
# 3.5509999999999997

# %%
storage[[
    'Project_Capacity_MW', 'Storage_Capacity_MWh', 'Time', 'Generator_Model',
    'size', 'avg'
]][storage.Generator_Type == 'Battery: Lithium-ion'].sort_values(
    by='Project_Capacity_MW')
# Out:
#     Project_Capacity_MW  Storage_Capacity_MWh      Time  \
# 70                0.100              0.200000  2.000000
# 61                0.100              0.213152  2.131519
# 27                0.100              0.200000  2.000000
# 25                0.200              0.426304  2.131519
# 66                0.240              0.511565  2.131519
# 59                0.250              0.250000  1.000000
# 47                0.256              0.512000  2.000000
# 14                0.300              0.640000  2.133333
# 58                0.315              0.500000  1.587302
# 63                0.500              2.100000  4.200000
# 57                0.500              1.065760  2.131519
# 48                0.500              1.065760  2.131519
# 2                 1.000              1.300000  1.300000
# 62                1.200              1.200000  1.000000
# 19                1.200              1.200000  1.000000
# 31                1.200              1.200000  1.000000
# 24                1.200              1.200000  1.000000
# 30                2.000              2.260263  1.130132
# 50                2.000              2.000000  1.000000
# 0                 2.000              2.500000  1.250000
# 8                 2.000              2.000000  1.000000
# 52                2.500              5.000000  2.000000
# 42                2.900              3.800000  1.310345
# 22                3.000              3.390395  1.130132
# 46                3.750              3.750000  1.000000
# 43                4.000              4.800000  1.200000
# 67                4.400              4.060000  0.922727
# 17                4.800              5.900000  1.229167
# 11                6.000              6.000000  1.000000
# 39                6.000              6.000000  1.000000
# 38                7.200              7.200000  1.000000
# 40               10.000              5.000000  0.500000
# 6                10.000              6.605772  0.660577
# 12               10.000              6.970000  0.697000
# 28               10.000              6.605772  0.660577
# 33               10.000              6.605772  0.660577
# 3                10.000              5.000000  0.500000
# 36               15.000              9.908658  0.660577
# 53               20.000             20.000000  1.000000
# 10               20.000             20.000000  1.000000
# 9                20.000             10.000000  0.500000
# 60               20.000             13.211544  0.660577
# 7                20.000             10.000000  0.500000
# 45               22.000             11.000000  0.500000
# 64               25.000             12.500000  0.500000
# 1                29.000             29.000000  1.000000
# 51               35.000             17.500000  0.500000
# 23               40.000             27.650000  0.691250
# 65               49.000             24.500000  0.500000
# 54               49.000             50.000000  1.020408
# 44               49.990             24.995000  0.500000
# 5                   NaN                   NaN       NaN
#
#            Generator_Model    size       avg
# 70     A123 Systems Li-ion    tiny  2.131519
# 61     Lithium-ion Battery    tiny  2.131519
# 27     A123 Systems Li-ion    tiny  2.131519
# 25          Saft Intensium    tiny  2.131519
# 66                   Li120    tiny  2.131519
# 59                     BYD    tiny  2.131519
# 47         Tesla Powerpack    tiny  2.131519
# 14     Lithium-ion Battery    tiny  2.131519
# 58         Tesla Powerpack    tiny  2.131519
# 63         Tesla Powerpack    tiny  2.131519
# 57     Lithium-ion Battery    tiny  2.131519
# 48     Lithium-ion Battery    tiny  2.131519
# 2                   Y.Cube  medium  1.130132
# 62                     BYD  medium  1.130132
# 19     Lithium-ion Battery  medium  1.130132
# 31                     BYD  medium  1.130132
# 24     Lithium-ion Battery  medium  1.130132
# 30                    MLiX  medium  1.130132
# 50         Tesla Powerpack  medium  1.130132
# 0          Tesla Powerpack  medium  1.130132
# 8                   EssPro  medium  1.130132
# 52     A123 Systems Li-ion  medium  1.130132
# 42                     BYD  medium  1.130132
# 22                  Y.Cube  medium  1.130132
# 46     Lithium-ion Battery  medium  1.130132
# 43         Tesla Powerpack  medium  1.130132
# 67        Powerstorage TPS  medium  1.130132
# 17     Lithium-ion Battery  medium  1.130132
# 11                     BYD  medium  1.130132
# 39              SieStorage  medium  1.130132
# 38     Lithium-ion Battery  medium  1.130132
# 40     Lithium-ion Battery   large  0.660577
# 6      Lithium-ion Battery   large  0.660577
# 12  LG Chem Battery Module   large  0.660577
# 28               Advancion   large  0.660577
# 33                     BYD   large  0.660577
# 3                    Nidec   large  0.660577
# 36     Lithium-ion Battery   large  0.660577
# 53                     BYD   large  0.660577
# 10     Lithium-ion Battery   large  0.660577
# 9                      GSS   large  0.660577
# 60  LG Chem Battery Module   large  0.660577
# 7      Lithium-ion Battery   large  0.660577
# 45                  BMW-i3   large  0.660577
# 64     Lithium-ion Battery   large  0.660577
# 1      Lithium-ion Battery   large  0.660577
# 51     Lithium-ion Battery   large  0.660577
# 23  LG Chem Battery Module   large  0.660577
# 65                   Nidec   large  0.660577
# 54     Lithium-ion Battery   large  0.660577
# 44     Lithium-ion Battery   large  0.660577
# 5      Lithium-ion Battery     nan       NaN

# %%
print str(wind.Project_Capacity_MW[wind.Project_Capacity_MW >=1].sum())
print str(wind.Project_Capacity_MW[wind.Project_Capacity_MW <1].sum())
# Out:
# 12496.29
# 439.935

# %%
wind.head()
# Out:
#                        Project  Project_Capacity_MW     Type  \
# 0    Abbey Road, 209 Turbine 1                0.250  onshore
# 1    Abbey Road, 209 Turbine 2                0.250  onshore
# 2                 Aberffrydlan                0.225  onshore
# 3  Abergwaun Community Turbine                0.225  onshore
# 4                  ABP Newport                2.350  onshore
#
#    Storage_Capacity_MWh                       Developer  \
# 0                   NaN                     Wind NI Ltd
# 1                   NaN                     Wind NI Ltd
# 2                   NaN  Landowner (private or company)
# 3                   NaN         Community Owned Project
# 4                   NaN        Associated British Ports
#
#                                    Owner Generator_Make Generator_Model  \
# 0                     Wind NI Ltd (100%)          Bonus           Bonus
# 1      Albion Community Power plc (100%)         Vestas      Vestas V39
# 2  Landowner (private or company) (100%)            NaN             NaN
# 3         Community Owned Project (100%)      Endurance   Endurance X29
# 4        Associated British Ports (100%)        Enercon     Enercon E82
#
#    Number_of_Generators  Generator_Capacity          ...           \
# 0                     1               0.250          ...
# 1                     1               0.250          ...
# 2                     1                 NaN          ...
# 3                     1               0.225          ...
# 4                     1               2.350          ...
#
#   Decision_Date    Decision_Note Appeal_Decision_Date Appeal_Decision_Note  \
# 0    16/01/2014  Approved (LPA)                   NaN                  NaN
# 1    25/09/2014  Approved (LPA)                   NaN                  NaN
# 2    29/09/2015  Approved (LPA)                   NaN                  NaN
# 3    08/01/2014   Refused (LPA)            01/08/2014  Approved on appeal
# 4    01/11/2012  Approved (LPA)                   NaN                  NaN
#
#   Construction_Date              Construction_Note Commissioned_Date  \
# 0        01/10/2016  Under construction [Estimate]        21/01/2017
# 1        01/08/2015  Under construction [Estimate]        21/11/2016
# 2        14/01/2016  Under construction [Estimate]        01/07/2016
# 3        29/06/2015            Under construction         08/10/2015
# 4        01/11/2013  Under construction [Estimate]        01/04/2014
#
#    Commissioned_Note  ResubmittedByProject ResubmissionOfProject
# 0                NaN                   NaN                   NaN
# 1                NaN                   NaN                   NaN
# 2                NaN                   NaN                   NaN
# 3                NaN                   NaN                   NaN
# 4         [Estimate]                   NaN                   NaN
#
# [5 rows x 45 columns]

# %%
wind.columns
# Out:
# Index([u'Project', u'Project_Capacity_MW', u'Type', u'Storage_Capacity_MWh',
#        u'Developer', u'Owner', u'Generator_Make', u'Generator_Model',
#        u'Number_of_Generators', u'Generator_Capacity', u'Generator_Type',
#        u'Country', u'County', u'UK_Region', u'Location', u'Sea_area', u'Lpa',
#        u'Latitude_Decimal', u'Longitude_Decimal', u'UKNatGridRef',
#        u'Hub_Height', u'Tip_Height', u'Rotor_Diameter', u'Summary_Status',
#        u'Status', u'Status_Date', u'SupersedeMethod', u'SupersedeByProject',
#        u'SupersededMethod', u'SupersededProject', u'Colocated_Grid',
#        u'Colocated_Grid_Detail', u'History', u'Submitted_Date',
#        u'Submitted_Note', u'Decision_Date', u'Decision_Note',
#        u'Appeal_Decision_Date', u'Appeal_Decision_Note', u'Construction_Date',
#        u'Construction_Note', u'Commissioned_Date', u'Commissioned_Note',
#        u'ResubmittedByProject', u'ResubmissionOfProject'],
#       dtype='object')

# %%
retired_battery.Generator_Type.unique()
# Out:
# Index([u'Project', u'Project_Capacity_MW', u'Type', u'Storage_Capacity_MWh',
#        u'Developer', u'Owner', u'Generator_Make', u'Generator_Model',
#        u'Number_of_Generators', u'Generator_Capacity', u'Generator_Type',
#        u'Country', u'County', u'UK_Region', u'Location', u'Sea_area', u'Lpa',
#        u'Latitude_Decimal', u'Longitude_Decimal', u'UKNatGridRef',
#        u'Hub_Height', u'Tip_Height', u'Rotor_Diameter', u'Summary_Status',
#        u'Status', u'Status_Date', u'SupersedeMethod', u'SupersedeByProject',
#        u'SupersededMethod', u'SupersededProject', u'Colocated_Grid',
#        u'Colocated_Grid_Detail', u'History', u'Submitted_Date',
#        u'Submitted_Note', u'Decision_Date', u'Decision_Note',
#        u'Appeal_Decision_Date', u'Appeal_Decision_Note', u'Construction_Date',
#        u'Construction_Note', u'Commissioned_Date', u'Commissioned_Note',
#        u'ResubmittedByProject', u'ResubmissionOfProject'],
#       dtype='object')

# %%
battery.Generator_Type.unique()
# Out:
# array(['Battery: Lithium-ion', nan, 'Pumped hydropower',
#        'Battery: Lead-acid', 'Battery: Redox flow', 'Liquefied air',
#        'Battery: Lithium-titanite'], dtype=object)

# %%
storage.sort_values(by='Project_Capacity_MW',ascending=False)
# Out:
#                                               Project  Project_Capacity_MW  \
# 16                            Dinorwig Pumped Storage             1728.000
# 15                            Cruachan Pumped Storage              440.000
# 20                          Ffestiniog Pumped Storage              360.000
# 21                              Foyers Pumped Storage              305.000
# 44                             Pelham Battery Storage               49.990
# 65                      West Burton B Battery Storage               49.000
# 54                          Roosecote Battery Storage               49.000
# 23                        Glassenbury Battery Storage               40.000
# 51                       Port of Tyne Battery Storage               35.000
# 1                           Aylesford Battery Storage               29.000
# 64                          Tynemouth Battery Storage               25.000
# 45                      Pen y Cymoedd Battery Storage               22.000
# 9                       Carnegie Road Battery Storage               20.000
# 10                     Claredown Farm Battery Storage               20.000
# 53                          Rock Farm Battery Storage               20.000
# 7                            Broxburn Battery Storage               20.000
# 60                            Staunch Battery Storage               20.000
# 36                          Lockleaze Battery Storage               15.000
# 28                            Kilroot Battery Storage               10.000
# 40                           Nevendon Battery Storage               10.000
# 55                    Roundponds Farm Battery Storage               10.000
# 29                    Kings Barn Farm Battery Storage               10.000
# 33                      Leverton Farm Battery Storage               10.000
# 12                            Cleator Battery Storage               10.000
# 3                                   Blackburn Meadows               10.000
# 6                         Breach Farm Battery Storage               10.000
# 34                        Littlebrook Battery Storage                8.000
# 38                          Mill Farm Battery Storage                7.200
# 56                            Rufford Battery Storage                7.000
# 11        Clayhill Farm Solar Phase 2 Battery Storage                6.000
# ..                                                ...                  ...
# 50                            Plessey Battery Storage                2.000
# 8                          Burbo Bank Battery Storage                2.000
# 0                          Arsenal FC Battery Storage                2.000
# 30             Kirkwall Power Station Battery Storage                2.000
# 69                  Willersey Energy Storage Facility                1.400
# 62               Thrybergh Hydropower Battery Storage                1.200
# 26          Heywood Grange Solar Farm Battery Storage                1.200
# 19               Fell View Solar Farm Battery Storage                1.200
# 31             Knottingley Hydropower Battery Storage                1.200
# 4          Blue House Farm Solar Farm Battery Storage                1.200
# 24               Grimsargh Solar Farm Battery Storage                1.200
# 68           Willenhall Battery Storage Demonstration                1.000
# 2                                             Batwind                1.000
# 48            Pierces Farm Solar Farm Battery Storage                0.500
# 57                  Salcey Solar Farm Battery Storage                0.500
# 63                        Trent Basin Battery Storage                0.500
# 58               Shetland Tidal Array Battery Storage                0.315
# 14             Copley Wood Solar Farm Battery Storage                0.300
# 47  Philip Dennis Foodservice (Mullacott) Battery ...                0.256
# 59              Slepe Farm Solar Farm Battery Storage                0.250
# 66                       Western International Market                0.240
# 25                             Hemsby Battery Storage                0.200
# 37                  Lotus Engineering Battery Storage                0.100
# 61               The Gyle Premier Inn Battery Storage                0.100
# 27               High Northgate Battery Storage Pilot                0.100
# 70                Wooler Ramsey Battery Storage Pilot                0.100
# 41                         Olde House Battery Storage                0.090
# 5              Bourne Park Solar Farm Battery Storage                  NaN
# 18                          Fair Isle Battery Storage                  NaN
# 35               Littleton Solar Farm Battery Storage                  NaN
#
#        Type  Storage_Capacity_MWh  \
# 16  storage              9100.000
# 15  storage              9680.000
# 20  storage              2160.000
# 21  storage              6300.000
# 44  storage                24.995
# 65  storage                24.500
# 54  storage                50.000
# 23  storage                27.650
# 51  storage                17.500
# 1   storage                29.000
# 64  storage                12.500
# 45  storage                11.000
# 9   storage                10.000
# 10  storage                20.000
# 53  storage                20.000
# 7   storage                10.000
# 60  storage                   NaN
# 36  storage                   NaN
# 28  storage                   NaN
# 40  storage                 5.000
# 55  storage                10.000
# 29  storage                   NaN
# 33  storage                   NaN
# 12  storage                 6.970
# 3   storage                 5.000
# 6   storage                   NaN
# 34  storage                   NaN
# 38  storage                 7.200
# 56  storage                   NaN
# 11  storage                 6.000
# ..      ...                   ...
# 50  storage                 2.000
# 8   storage                 2.000
# 0   storage                 2.500
# 30  storage                   NaN
# 69  storage                   NaN
# 62  storage                 1.200
# 26  storage                   NaN
# 19  storage                 1.200
# 31  storage                 1.200
# 4   storage                   NaN
# 24  storage                 1.200
# 68  storage                 0.500
# 2   storage                 1.300
# 48  storage                   NaN
# 57  storage                   NaN
# 63  storage                 2.100
# 58  storage                 0.500
# 14  storage                 0.640
# 47  storage                 0.512
# 59  storage                 0.250
# 66  storage                   NaN
# 25  storage                   NaN
# 37  storage                   NaN
# 61  storage                   NaN
# 27  storage                 0.200
# 70  storage                 0.200
# 41  storage                 1.080
# 5   storage                   NaN
# 18  storage                   NaN
# 35  storage                   NaN
#
#                                           Developer  \
# 16                                              NaN
# 15                                              NaN
# 20                                              NaN
# 21                                              NaN
# 44                           Statera Energy Limited
# 65                                   EDF Renewables
# 54              Centrica Distributed Generation Ltd
# 23        Low Carbon Storage Investment Company Ltd
# 51               Renewable Energy Systems Ltd (RES)
# 1              Battery Energy Storage Solutions Ltd
# 64   Element Power Northern Europe Developments Ltd
# 45                        Vattenfall Wind Power Ltd
# 9                                   Shaw-Energi Ltd
# 10                            Energy Reservoirs Ltd
# 53                            Energy Reservoirs Ltd
# 7                Renewable Energy Systems Ltd (RES)
# 60                                Noriker Power Ltd
# 36                 Aura Power Storage Solutions Ltd
# 28                                  AES Corporation
# 40                        Gridserve UK projects Ltd
# 55                                 Surface Planning
# 29                        Green Hedge Energy UK Ltd
# 33                        Green Hedge Energy UK Ltd
# 12        Low Carbon Storage Investment Company Ltd
# 3                                   E.ON UK CHP Ltd
# 6                         Green Hedge Energy UK Ltd
# 34                      Camborne Energy Storage Ltd
# 38                                       Anesco Ltd
# 56               Renewable Energy Systems Ltd (RES)
# 11                                       Anesco Ltd
# ..                                              ...
# 50                                   KiWi Power Ltd
# 8                                   Orsted (UK) Ltd
# 0                                   Pivot Power LLP
# 30                                          SSE plc
# 69                                        Belectric
# 62                         Yorkshire Hydropower Ltd
# 26                                       Anesco Ltd
# 19                                       Anesco Ltd
# 31                          Northern Hydropower Ltd
# 4                                        Anesco Ltd
# 24                                       Anesco Ltd
# 68                          University of Sheffield
# 2                                       Equinor ASA
# 48                                       Anesco Ltd
# 57                                       Anesco Ltd
# 63                   Landowner (private or company)
# 58                              Nova Innovation Ltd
# 14                                   BSR Energy Ltd
# 47                   Landowner (private or company)
# 59                                       Anesco Ltd
# 66                       London Borough of Hounslow
# 25                                UK Power Networks
# 37                      Mosscliff Environmental Ltd
# 61                 E.ON Climate & Renewables UK Ltd
# 27                           Northern Powergrid Ltd
# 70                           Northern Powergrid Ltd
# 41                             redT energy (UK) Ltd
# 5                                        Anesco Ltd
# 18                Fair Isle Electricity Company Ltd
# 35  Lightsource BP Renewable Energy Investments Ltd
#
#                                                 Owner Generator_Make  \
# 16                         First Hydro Company (100%)            GEC
# 15                ScottishPower Generation Ltd (100%)            Tbc
# 20                         First Hydro Company (100%)            Tbc
# 21                          SSE Generation Ltd (100%)            Tbc
# 44                      Statera Energy Limited (100%)            Tbc
# 65                              EDF Renewables (100%)      Nidec ASI
# 54         Centrica Distributed Generation Ltd (100%)            Tbc
# 23                              VLC Energy Ltd (100%)        LG Chem
# 51                         Foresight Group LLP (100%)            Tbc
# 1         Battery Energy Storage Solutions Ltd (100%)            Tbc
# 64                                 Enel S.p.A. (100%)            Tbc
# 45                   Vattenfall Wind Power Ltd (100%)            BMW
# 9                                   Orsted A/S (100%)         NEC ES
# 10        Battery Energy Storage Solutions Ltd (100%)            Tbc
# 53                                Eelpower Ltd (100%)            BYD
# 7   The Renewables Infrastructure Group Ltd (TRIG)...            Tbc
# 60                               Gresham House (100%)        LG Chem
# 36                           Noriker Power Ltd (100%)            Tbc
# 28                             AES Corporation (100%)        Fluence
# 40                         Foresight Group LLP (100%)            Tbc
# 55                               Hazel Capital (100%)            NaN
# 29        Battery Energy Storage Solutions Ltd (100%)            NaN
# 33                                Eelpower Ltd (100%)            BYD
# 12                              VLC Energy Ltd (100%)        LG Chem
# 3                              E.ON UK CHP Ltd (100%)      Nidec ASI
# 6                                   Anesco Ltd (100%)            Tbc
# 34                               Gresham House (100%)            NaN
# 38                                         ESB (100%)            Tbc
# 56                               Gresham House (100%)            NaN
# 11                                  Anesco Ltd (100%)            BYD
# ..                                                ...            ...
# 50                              KiWi Power Ltd (100%)          Tesla
# 8                              Orsted (UK) Ltd (100%)            ABB
# 0                              Pivot Power LLP (100%)          Tesla
# 30                                     SSE plc (100%)            MHI
# 69                                   Belectric (100%)      Belectric
# 62                                Eelpower Ltd (100%)            BYD
# 26                                  Anesco Ltd (100%)            NaN
# 19                                  Anesco Ltd (100%)            Tbc
# 31                                Eelpower Ltd (100%)            BYD
# 4                                   Anesco Ltd (100%)            NaN
# 24                                  Anesco Ltd (100%)            Tbc
# 68                     University of Sheffield (100%)        Toshiba
# 2                     Equinor ASA (75%); Masdar (25%)       Younicos
# 48                       NextEnergy Solar Fund (100%)            Tbc
# 57                       NextEnergy Solar Fund (100%)            Tbc
# 63              Landowner (private or company) (100%)          Tesla
# 58                         Nova Innovation Ltd (100%)          Tesla
# 14                              BSR Energy Ltd (100%)            Tbc
# 47              Landowner (private or company) (100%)          Tesla
# 59                       Farm Power Apollo Ltd (100%)            BYD
# 66                  London Borough of Hounslow (100%)        Tesvolt
# 25                           UK Power Networks (100%)           Saft
# 37                 Mosscliff Environmental Ltd (100%)            NaN
# 61            E.ON Climate & Renewables UK Ltd (100%)            Tbc
# 27                      Northern Powergrid Ltd (100%)    A123 Sytems
# 70                      Northern Powergrid Ltd (100%)    A123 Sytems
# 41                        redT energy (UK) Ltd (100%)           redT
# 5                        Farm Power Apollo Ltd (100%)            Tbc
# 18           Fair Isle Electricity Company Ltd (100%)            Tbc
# 35  Lightsource BP Renewable Energy Investments Lt...            NaN
#
#             Generator_Model  Number_of_Generators  Generator_Capacity  \
# 16   GEC Francis Reversible                   6.0             288.000
# 15  Reversible Pump Turbine                   4.0             110.000
# 20           Vertical Shaft                   4.0              90.000
# 21           Vertical Shaft                   2.0             150.000
# 44      Lithium-ion Battery                  11.0               4.545
# 65                    Nidec                  20.0               2.450
# 54      Lithium-ion Battery                   1.0              49.000
# 23   LG Chem Battery Module                   7.0               5.714
# 51      Lithium-ion Battery                   9.0               3.889
# 1       Lithium-ion Battery                  23.0               1.260
# 64      Lithium-ion Battery                  14.0               1.786
# 45                   BMW-i3                   5.0               4.400
# 9                       GSS                   3.0               6.667
# 10      Lithium-ion Battery                  16.0               1.250
# 53                      BYD                  16.0               1.250
# 7       Lithium-ion Battery                   6.0               3.333
# 60   LG Chem Battery Module                  10.0               2.000
# 36      Lithium-ion Battery                   8.0               1.875
# 28                Advancion                   1.0              10.000
# 40      Lithium-ion Battery                   3.0               3.333
# 55                      NaN                   5.0               2.000
# 29                      NaN                   1.0              10.000
# 33                      BYD                   8.0               1.250
# 12   LG Chem Battery Module                   2.0               5.000
# 3                     Nidec                   1.0              10.000
# 6       Lithium-ion Battery                  10.0               1.000
# 34                      NaN                   2.0               4.000
# 38      Lithium-ion Battery                   6.0               1.200
# 56                      NaN                   2.0                 NaN
# 11                      BYD                   5.0               1.200
# ..                      ...                   ...                 ...
# 50          Tesla Powerpack                  25.0               0.080
# 8                    EssPro                   4.0               0.500
# 0           Tesla Powerpack                   NaN                 NaN
# 30                     MLiX                   3.0               0.667
# 69       LION EBU Lead-acid                   1.0               1.400
# 62                      BYD                   1.0               1.200
# 26                      NaN                   1.0               1.200
# 19      Lithium-ion Battery                   1.0               1.200
# 31                      BYD                   1.0               1.200
# 4                       NaN                   1.0               1.200
# 24      Lithium-ion Battery                   1.0               1.200
# 68      Toshiba Li-Titanate                   1.0               1.000
# 2                    Y.Cube                   2.0               0.500
# 48      Lithium-ion Battery                   1.0               0.500
# 57      Lithium-ion Battery                   1.0               0.500
# 63          Tesla Powerpack                  10.0                 NaN
# 58          Tesla Powerpack                   3.0               0.105
# 14      Lithium-ion Battery                   1.0               0.300
# 47          Tesla Powerpack                   1.0               0.256
# 59                      BYD                   1.0                 NaN
# 66                    Li120                   2.0               0.120
# 25           Saft Intensium                   1.0               0.200
# 37                      NaN                   1.0               0.100
# 61      Lithium-ion Battery                   1.0               0.100
# 27      A123 Systems Li-ion                   1.0               0.100
# 70      A123 Systems Li-ion                   1.0               0.100
# 41                RedT VRFM                   6.0               0.015
# 5       Lithium-ion Battery                   1.0                 NaN
# 18                Lead Acid                   1.0                 NaN
# 35                      NaN                   2.0                 NaN
#
#             ...          Decision_Date    Decision_Note Appeal_Decision_Date  \
# 16          ...                    NaN              NaN                  NaN
# 15          ...                    NaN              NaN                  NaN
# 20          ...                    NaN              NaN                  NaN
# 21          ...                    NaN              NaN                  NaN
# 44          ...             18/10/2016  Approved (LPA)                   NaN
# 65          ...             30/09/2016  Approved (LPA)                   NaN
# 54          ...             16/08/2016  Approved (LPA)                   NaN
# 23          ...             21/10/2016  Approved (LPA)                   NaN
# 51          ...             21/10/2016  Approved (LPA)                   NaN
# 1           ...             05/12/2017  Approved (LPA)                   NaN
# 64          ...             12/10/2016  Approved (LPA)                   NaN
# 45          ...             27/02/2017  Approved (S36)                   NaN
# 9           ...             15/12/2016  Approved (LPA)                   NaN
# 10          ...             05/06/2017  Approved (LPA)                   NaN
# 53          ...             23/12/2016  Approved (LPA)                   NaN
# 7           ...             25/11/2016   Refused (LPA)            06/03/2017
# 60          ...             19/05/2016  Approved (LPA)                   NaN
# 36          ...             05/05/2017  Approved (LPA)                   NaN
# 28          ...                    NaN              NaN                  NaN
# 40          ...             17/02/2017  Approved (LPA)                   NaN
# 55          ...             07/12/2017  Approved (LPA)                   NaN
# 29          ...             04/10/2016  Approved (LPA)                   NaN
# 33          ...             30/09/2016  Approved (LPA)                   NaN
# 12          ...             27/10/2016  Approved (LPA)                   NaN
# 3           ...             16/08/2016  Approved (LPA)                   NaN
# 6           ...             11/10/2016  Approved (LPA)                   NaN
# 34          ...             12/09/2016  Approved (LPA)                   NaN
# 38          ...             10/11/2017  Approved (LPA)                   NaN
# 56          ...             10/10/2016  Approved (LPA)                   NaN
# 11          ...             30/11/2016  Approved (LPA)                   NaN
# ..          ...                    ...              ...                  ...
# 50          ...             06/07/2017  Approved (LPA)                   NaN
# 8           ...             14/06/2017  Approved (LPA)                   NaN
# 0           ...                    NaN              NaN                  NaN
# 30          ...             17/08/2012  Approved (LPA)                   NaN
# 69          ...             23/12/2016  Approved (LPA)                   NaN
# 62          ...             14/12/2016  Approved (LPA)                   NaN
# 26          ...             06/01/2017  Approved (LPA)                   NaN
# 19          ...             17/03/2016  Approved (LPA)                   NaN
# 31          ...             09/05/2017  Approved (LPA)                   NaN
# 4           ...             20/06/2016  Approved (LPA)                   NaN
# 24          ...             17/03/2016  Approved (LPA)                   NaN
# 68          ...                    NaN              NaN                  NaN
# 2           ...             09/05/2017  Approved (LPA)                   NaN
# 48          ...             11/12/2015  Approved (LPA)                   NaN
# 57          ...             12/05/2016  Approved (LPA)                   NaN
# 63          ...             15/02/2017  Approved (LPA)                   NaN
# 58          ...             31/05/2017  Approved (LPA)                   NaN
# 14          ...             14/05/2014  Approved (LPA)                   NaN
# 47          ...                    NaN              NaN                  NaN
# 59          ...                    NaN              NaN                  NaN
# 66          ...                    NaN              NaN                  NaN
# 25          ...                    NaN              NaN                  NaN
# 37          ...             13/06/2014  Approved (LPA)                   NaN
# 61          ...                    NaN              NaN                  NaN
# 27          ...                    NaN              NaN                  NaN
# 70          ...                    NaN              NaN                  NaN
# 41          ...                    NaN              NaN                  NaN
# 5           ...                    NaN              NaN                  NaN
# 18          ...             01/08/2017  Approved (LPA)                   NaN
# 35          ...             09/12/2014  Approved (LPA)                   NaN
#
#    Appeal_Decision_Note Construction_Date              Construction_Note  \
# 16                  NaN        01/01/1974            Under construction
# 15                  NaN               NaN                            NaN
# 20                  NaN               NaN                            NaN
# 21                  NaN               NaN                            NaN
# 44                  NaN        01/07/2017  Under construction [Estimate]
# 65                  NaN        26/07/2017            Under construction
# 54                  NaN        01/03/2017            Under construction
# 23                  NaN               NaN                            NaN
# 51                  NaN        21/06/2017            Under construction
# 1                   NaN        01/01/2018  Under construction [Estimate]
# 64                  NaN               NaN                            NaN
# 45                  NaN               NaN                            NaN
# 9                   NaN        01/06/2018  Under construction [Estimate]
# 10                  NaN               NaN                            NaN
# 53                  NaN               NaN                            NaN
# 7   Approved on appeal         14/08/2017            Under construction
# 60                  NaN               NaN                            NaN
# 36                  NaN        20/06/2017            Under construction
# 28                  NaN               NaN                            NaN
# 40                  NaN        21/07/2017            Under construction
# 55                  NaN        01/01/2018  Under construction [Estimate]
# 29                  NaN               NaN                            NaN
# 33                  NaN        25/07/2017            Under construction
# 12                  NaN               NaN                            NaN
# 3                   NaN        07/04/2017            Under construction
# 6                   NaN               NaN                            NaN
# 34                  NaN        01/06/2017  Under construction [Estimate]
# 38                  NaN        01/02/2018            Under construction
# 56                  NaN               NaN                            NaN
# 11                  NaN               NaN                            NaN
# ..                  ...               ...                            ...
# 50                  NaN               NaN                            NaN
# 8                   NaN        30/08/2017  Under construction [Estimate]
# 0                   NaN               NaN                            NaN
# 30                  NaN               NaN                            NaN
# 69                  NaN               NaN                            NaN
# 62                  NaN               NaN                            NaN
# 26                  NaN               NaN                            NaN
# 19                  NaN               NaN                            NaN
# 31                  NaN               NaN                            NaN
# 4                   NaN               NaN                            NaN
# 24                  NaN               NaN                            NaN
# 68                  NaN               NaN                            NaN
# 2                   NaN               NaN                            NaN
# 48                  NaN               NaN                            NaN
# 57                  NaN               NaN                            NaN
# 63                  NaN        24/01/2018            Under construction
# 58                  NaN        01/10/2018   Partial Operation [Estimate]
# 14                  NaN               NaN                            NaN
# 47                  NaN               NaN                            NaN
# 59                  NaN               NaN                            NaN
# 66                  NaN               NaN                            NaN
# 25                  NaN               NaN                            NaN
# 37                  NaN               NaN                            NaN
# 61                  NaN               NaN                            NaN
# 27                  NaN               NaN                            NaN
# 70                  NaN        30/11/2012            Under construction
# 41                  NaN        18/07/2017            Under construction
# 5                   NaN               NaN                            NaN
# 18                  NaN        07/05/2018  Under construction [Estimate]
# 35                  NaN        30/12/2014            Under construction
#
#    Commissioned_Date  Commissioned_Note  ResubmittedByProject  \
# 16        09/05/1984                NaN                   NaN
# 15        15/10/1965                NaN                   NaN
# 20        10/08/1963                NaN                   NaN
# 21        31/12/1975                NaN                   NaN
# 44        31/12/2017                NaN                   NaN
# 65        22/06/2018                NaN                   NaN
# 54        19/12/2018                NaN                   NaN
# 23        09/01/2018                NaN                   NaN
# 51        30/06/2018                NaN                   NaN
# 1         28/02/2018                NaN                   NaN
# 64        12/06/2018                NaN                   NaN
# 45        18/05/2018                NaN                   NaN
# 9         24/12/2018                NaN                   NaN
# 10        28/02/2018                NaN                   NaN
# 53        30/06/2018                NaN                   NaN
# 7         30/06/2018                NaN                   NaN
# 60        01/05/2017                NaN                   NaN
# 36        28/07/2017                NaN                   NaN
# 28        05/01/2016                NaN                   NaN
# 40        01/03/2018         [Estimate]                   NaN
# 55        30/04/2018                NaN                   NaN
# 29        31/08/2017                NaN                   NaN
# 33        21/11/2017                NaN                   NaN
# 12        09/01/2018                NaN                   NaN
# 3         09/10/2017                NaN                   NaN
# 6         20/08/2018         [Estimate]                   NaN
# 34        31/12/2017                NaN                   NaN
# 38        30/04/2018                NaN                   NaN
# 56        16/08/2017         [Estimate]                   NaN
# 11        26/09/2017                NaN                   NaN
# ..               ...                ...                   ...
# 50        06/06/2018                NaN                   NaN
# 8         01/12/2017         [Estimate]                   NaN
# 0         26/11/2018                NaN                   NaN
# 30        15/08/2013                NaN                   NaN
# 69        30/06/2017                NaN                   NaN
# 62        22/03/2018                NaN                   NaN
# 26        08/09/2018         [Estimate]                   NaN
# 19        15/07/2018         [Estimate]                   NaN
# 31        22/03/2018                NaN                   NaN
# 4         31/08/2016         [Estimate]                   NaN
# 24        15/07/2018         [Estimate]                   NaN
# 68        17/03/2016                NaN                   NaN
# 2         27/06/2018                NaN                   NaN
# 48        30/05/2018         [Estimate]                   NaN
# 57        30/05/2018         [Estimate]                   NaN
# 63        04/06/2018                NaN                   NaN
# 58        30/10/2018                NaN                   NaN
# 14        31/12/2016         [Estimate]                   NaN
# 47        31/05/2018                NaN                   NaN
# 59        08/10/2014                NaN                   NaN
# 66        19/05/2016                NaN                   NaN
# 25        31/01/2014                NaN                   NaN
# 37        13/07/2018                NaN                   NaN
# 61        04/01/2019                NaN                   NaN
# 27        31/12/2013                NaN                   NaN
# 70        19/02/2014                NaN                   NaN
# 41        07/09/2017                NaN                   NaN
# 5         21/12/2016                NaN                   NaN
# 18        12/10/2018                NaN                   NaN
# 35        23/03/2015                NaN                   NaN
#
#    ResubmissionOfProject
# 16                   NaN
# 15                   NaN
# 20                   NaN
# 21                   NaN
# 44                   NaN
# 65                   NaN
# 54                   NaN
# 23                   NaN
# 51                   NaN
# 1                    NaN
# 64                   NaN
# 45                   NaN
# 9                    NaN
# 10                   NaN
# 53                   NaN
# 7                    NaN
# 60                   NaN
# 36                   NaN
# 28                   NaN
# 40                   NaN
# 55                   NaN
# 29                   NaN
# 33                   NaN
# 12                   NaN
# 3                    NaN
# 6                    NaN
# 34                   NaN
# 38                   NaN
# 56                   NaN
# 11                   NaN
# ..                   ...
# 50                   NaN
# 8                    NaN
# 0                    NaN
# 30                   NaN
# 69                   NaN
# 62                   NaN
# 26                   NaN
# 19                   NaN
# 31                   NaN
# 4                    NaN
# 24                   NaN
# 68                   NaN
# 2                    NaN
# 48                   NaN
# 57                   NaN
# 63                   NaN
# 58                   NaN
# 14                   NaN
# 47                   NaN
# 59                   NaN
# 66                   NaN
# 25                   NaN
# 37                   NaN
# 61                   NaN
# 27                   NaN
# 70                   NaN
# 41                   NaN
# 5                    NaN
# 18                   NaN
# 35                   NaN
#
# [71 rows x 45 columns]

# %%
battery[['Project_Capacity_MW','Storage_Capacity_MWh','Generator_Type']].groupby(['Generator_Type']).sum()
# Out:
#                            Project_Capacity_MW  Storage_Capacity_MWh
# Generator_Type
# Battery: Lead-acid                       1.400                   NaN
# Battery: Lithium-ion                   535.701               337.627
# Battery: Lithium-titanite                1.000                 0.500
# Battery: Redox flow                      0.090                 1.080
# Liquefied air                            5.000                15.000
# Pumped hydropower                     2833.000             20940.000
